# %% [markdown]
# # YOLOv8 Binary Object Detection and Cropping Pipeline

# %% [markdown]
# ## Instructions on How to use this notebook:
# 1. Click on Runtime -> Change runtime type -> Click t4 GPU (this is the free option if you have paid subscription feel free to use other GPU)
#
# 2. Next Use the side to upload your image file
#
# 3. Replace path below with your image path. To do this use sidebar and right click on image file name ans select copy path. Paste this into `org_image` variable in the cell below and run the cell

# %%
org_img = "/content/W5_20220523_5_ST220265_A.JPG"

# %% [markdown]
# Run the cell below to download the requirements and  model weights and install all required modules

# %%
# !pip install gdown
# !gdown 1noapdtUBmjrV9_H0sP0qSKQpHNftq080 -O requirements.txt
# !gdown 14iCE6ps3WOSHPAmM5tzlrEX_IiROb4Zr -O cls_model.keras
# !gdown 1IdQXwGsizccY9TSPiL2dMmVFUAZ58NRr -O detect_model.pt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1noapdtUBmjrV9_H0sP0qSKQpHNftq080
# To: /content/requirements.txt
# 100% 745/745 [00:00<00:00, 4.29MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=14iCE6ps3WOSHPAmM5tzlrEX_IiROb4Zr
# From (redirected): https://drive.google.com/uc?id=14iCE6ps3WOSHPAmM5tzlrEX_IiROb4Zr&confirm=t&uuid=46e04709-b4f7-451d-80e3-ca42380ba6e4
# To: /content/cls_model.keras
# 100% 290M/290M [00:01<00:00, 192MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=13HpjrHqYLRgkZJk419flO_HKHuqwIRa_
# To: /content/detect_model.pt
# 100% 5.54M/5.54M [00:00<00:00, 199MB/s]

# %% [markdown]
# ## Run the script below runs the inference on the image.
# A summary of results is saved in `class_summary.csv` and the each image path, predicted class and confidence is saved in `detailed_predictions.csv`. Individual cropped images in their corresponding prdiction folders are save in `results`. The `coco_annotations.json` file contains the annotations for the image in coco format.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from collections import defaultdict
import csv
import pandas as pd
from sahi import AutoDetectionModel
from sahi.predict import get_sliced_prediction
import json

crop_dir = 'cropped_results'
output_dir = 'results'
detailed_csv_path = 'detailed_predictions.csv'
summary_csv_path = 'class_summary.csv'
coco_json_path = 'coco_annotations.json'

# =======================
class_names = ['Caddisfly', 'Dipteran', 'Mayfly', 'Other', 'Stonefly', 'Terrestrial']
class_thresholds = {
    0: 0.4,   # Caddisfly
    1: 0.4,   # Dipteran
    2: 0.4,   # Mayfly
    3: 0.0,   # Other
    4: 0.4,   # Stonefly
    5: 0.4    # Terrestrial
}
OTHER_IDX = 3  # Index for "Other" class
img_size = (224, 224)

# =======================
# 1. Load Classification Model
# =======================
if tf.config.list_physical_devices('GPU'):
    with tf.device('/GPU:0'):
        model_cls = load_model('/content/cls_model.keras')
else:
    model_cls = load_model('/content/cls_model.keras')

# =======================
# 2. Load Detection Model
# =======================
detection_model = AutoDetectionModel.from_pretrained(
    model_type="ultralytics",
    model_path='/content/detect_model.pt',
    confidence_threshold=0.2
)

# =======================
# 3. Get Sliced Prediction
# =======================
result = get_sliced_prediction(
    org_img,
    detection_model,
    slice_height=752,
    slice_width=752,
    overlap_height_ratio=0.3,
    overlap_width_ratio=0.3,
    postprocess_type="GREEDYNMM"
)

# =======================
# 4. Crop and Record Annotations
# =======================
def crop_predictions_from_sahi(image_path, sahi_result, conf_thresh=0.05):
    img = cv2.imread(image_path)
    crops = []
    annotations_map = {}
    for idx, obj in enumerate(sahi_result.object_prediction_list):
        if obj.score.value < conf_thresh:
            continue

        x1, y1, x2, y2 = map(int, obj.bbox.to_xyxy())
        crop = img[y1:y2, x1:x2]
        crops.append(crop)

        filename = f"insect_{idx + 1}.jpg"
        annotations_map[filename] = {
            "bbox": [x1, y1, x2 - x1, y2 - y1],
            "score": float(obj.score.value),
            "category": None
        }

    return crops, annotations_map

def save_crops(crops, save_dir, base_filename="crop"):
    os.makedirs(save_dir, exist_ok=True)
    for idx, crop in enumerate(crops):
        save_path = os.path.join(save_dir, f"{base_filename}_{idx + 1}.jpg")
        cv2.imwrite(save_path, crop)
    print(f"{len(crops)} cropped images saved to {save_dir}")

crops, annotations_map = crop_predictions_from_sahi(org_img, result)
save_crops(crops, save_dir=crop_dir, base_filename="insect")

# =======================
# 5. Classify & Update Annotations
# =======================
os.makedirs(output_dir, exist_ok=True)
for class_name in class_names:
    os.makedirs(os.path.join(output_dir, class_name), exist_ok=True)

class_counts = defaultdict(int)

with open(detailed_csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Image Name', 'Raw Prediction', 'Confidence', 'Threshold', 'Final Prediction'])

    for file_name in os.listdir(crop_dir):
        if not file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue

        img_path = os.path.join(crop_dir, file_name)
        img = image.load_img(img_path, target_size=img_size)
        img_array = image.img_to_array(img) / 255.0
        img_batch = np.expand_dims(img_array, axis=0)

        preds = model_cls.predict(img_batch, verbose=0)
        probs = preds[0]
        pred_idx = np.argmax(probs)
        raw_class = class_names[pred_idx]
        confidence = float(probs[pred_idx])
        threshold = class_thresholds.get(pred_idx, 0.5)

        if confidence >= threshold:
            final_idx = pred_idx
            rerouted = False
        else:
            final_idx = OTHER_IDX
            rerouted = True

        final_class = class_names[final_idx]
        class_counts[final_class] += 1

        writer.writerow([
            file_name,
            raw_class,
            round(confidence, 4),
            threshold,
            final_class
        ])

        # Annotate image with prediction
        plt.figure()
        plt.imshow(img)
        plt.title(f"{final_class} ({confidence:.2f})")
        plt.axis('off')
        save_path = os.path.join(output_dir, final_class, f"{os.path.splitext(file_name)[0]}_pred.png")
        plt.savefig(save_path)
        plt.close()

        # Update hash map
        if file_name in annotations_map:
            annotations_map[file_name]["category"] = final_class

        if rerouted:
            print(f"{file_name} → {raw_class} ({confidence:.2f}) ➡ rerouted to 'Other'")
        else:
            print(f"{file_name} → {final_class} ({confidence:.2f}) ✅")

# =======================
# 6. Save Summary CSV
# =======================
with open(summary_csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Class', 'Count'])
    for class_name in class_names:
        writer.writerow([class_name, class_counts[class_name]])

print(f"\nSummary CSV saved to: {summary_csv_path}")
print("Class Distribution:")
for cls, count in class_counts.items():
    print(f"{cls}: {count} times")


# =======================
# 7. Convert to COCO Format and Save
# =======================
def convert_to_coco(annotations_map, org_img_path, image_id=1):
    # Read image to get dimensions
    img = cv2.imread(org_img_path)
    if img is None:
        raise FileNotFoundError(f"Could not read image from path: {org_img_path}")
    height, width = img.shape[:2]

    categories = [{"id": i, "name": name} for i, name in enumerate(class_names)]
    images = [{
        "id": image_id,
        "file_name": os.path.basename(org_img_path),
        "height": height,
        "width": width
    }]
    annotations = []
    annotation_id = 1

    for fname, ann in annotations_map.items():
        if ann["category"] is None:
            continue
        category_id = class_names.index(ann["category"])
        coco_ann = {
            "id": annotation_id,
            "image_id": image_id,
            "category_id": category_id,
            "bbox": ann["bbox"],
            "area": ann["bbox"][2] * ann["bbox"][3],
            "iscrowd": 0
        }
        annotations.append(coco_ann)
        annotation_id += 1

    return {
        "images": images,
        "annotations": annotations,
        "categories": categories
    }
coco_dict = convert_to_coco(annotations_map, org_img)
with open(coco_json_path, 'w') as f:
    json.dump(coco_dict, f, indent=4)

print(f"COCO annotation JSON saved to {coco_json_path}")
# Out:
# Performing prediction on 9 slices.
# 295 cropped images saved to cropped_results
# insect_156.jpg → Dipteran (0.66) ✅
# insect_115.jpg → Other (0.49) ✅
# insect_133.jpg → Dipteran (0.93) ✅
# insect_111.jpg → Dipteran (0.90) ✅
# insect_295.jpg → Dipteran (0.66) ✅
# insect_281.jpg → Dipteran (0.67) ✅
# insect_137.jpg → Other (0.49) ✅
# insect_208.jpg → Dipteran (0.53) ✅
# insect_184.jpg → Dipteran (0.72) ✅
# insect_85.jpg → Dipteran (0.78) ✅
# insect_262.jpg → Dipteran (0.86) ✅
# insect_226.jpg → Dipteran (0.47) ✅
# insect_116.jpg → Dipteran (0.87) ✅
# insect_273.jpg → Dipteran (0.58) ✅
# insect_7.jpg → Dipteran (0.91) ✅
# insect_138.jpg → Dipteran (0.61) ✅
# insect_42.jpg → Dipteran (0.88) ✅
# insect_230.jpg → Other (0.62) ✅
# insect_40.jpg → Other (0.41) ✅
# insect_224.jpg → Dipteran (0.82) ✅
# insect_198.jpg → Dipteran (0.72) ✅
# insect_113.jpg → Dipteran (0.88) ✅
# insect_31.jpg → Dipteran (0.89) ✅
# insect_5.jpg → Dipteran (0.51) ✅
# insect_166.jpg → Dipteran (0.79) ✅
# insect_147.jpg → Dipteran (0.80) ✅
# insect_107.jpg → Dipteran (0.85) ✅
# insect_122.jpg → Dipteran (0.80) ✅
# insect_24.jpg → Dipteran (0.83) ✅
# insect_12.jpg → Dipteran (0.79) ✅
# insect_66.jpg → Dipteran (0.94) ✅
# insect_98.jpg → Dipteran (0.64) ✅
# insect_249.jpg → Dipteran (0.66) ✅
# insect_285.jpg → Dipteran (0.46) ✅
# insect_162.jpg → Dipteran (0.67) ✅
# insect_129.jpg → Dipteran (0.74) ✅
# insect_61.jpg → Dipteran (0.87) ✅
# insect_47.jpg → Dipteran (0.93) ✅
# insect_151.jpg → Dipteran (0.76) ✅
# insect_264.jpg → Other (0.60) ✅
# insect_91.jpg → Other (0.35) ✅
# insect_282.jpg → Dipteran (0.57) ✅
# insect_117.jpg → Dipteran (0.88) ✅
# insect_22.jpg → Dipteran (0.83) ✅
# insect_163.jpg → Other (0.37) ✅
# insect_204.jpg → Dipteran (0.76) ✅
# insect_99.jpg → Dipteran (0.53) ✅
# insect_13.jpg → Other (0.46) ✅
# insect_239.jpg → Dipteran (0.49) ✅
# insect_171.jpg → Dipteran (0.83) ✅
# insect_145.jpg → Dipteran (0.49) ✅
# insect_52.jpg → Dipteran (0.71) ✅
# insect_112.jpg → Dipteran (0.94) ✅
# insect_209.jpg → Dipteran (0.80) ✅
# insect_275.jpg → Dipteran (0.73) ✅
# insect_63.jpg → Dipteran (0.88) ✅
# insect_232.jpg → Dipteran (0.64) ✅
# insect_277.jpg → Dipteran (0.58) ✅
# insect_97.jpg → Dipteran (0.91) ✅
# insect_271.jpg → Dipteran (0.67) ✅
# insect_49.jpg → Dipteran (0.91) ✅
# insect_213.jpg → Dipteran (0.91) ✅
# insect_181.jpg → Dipteran (0.83) ✅
# insect_183.jpg → Dipteran (0.81) ✅
# insect_51.jpg → Dipteran (0.86) ✅
# insect_105.jpg → Other (0.65) ✅
# insect_72.jpg → Dipteran (0.87) ✅
# insect_68.jpg → Dipteran (0.87) ✅
# insect_18.jpg → Dipteran (0.90) ✅
# insect_288.jpg → Dipteran (0.91) ✅
# insect_229.jpg → Other (0.42) ✅
# insect_174.jpg → Dipteran (0.58) ✅
# insect_257.jpg → Dipteran (0.84) ✅
# insect_109.jpg → Dipteran (0.50) ✅
# insect_59.jpg → Terrestrial (0.50) ✅
# insect_73.jpg → Dipteran (0.63) ✅
# insect_186.jpg → Dipteran (0.68) ✅
# insect_89.jpg → Dipteran (0.54) ✅
# insect_211.jpg → Dipteran (0.66) ✅
# insect_289.jpg → Dipteran (0.72) ✅
# insect_48.jpg → Dipteran (0.91) ✅
# insect_291.jpg → Dipteran (0.34) ➡ rerouted to 'Other'
# insect_103.jpg → Dipteran (0.60) ✅
# insect_144.jpg → Dipteran (0.89) ✅
# insect_292.jpg → Dipteran (0.70) ✅
# insect_84.jpg → Dipteran (0.55) ✅
# insect_202.jpg → Dipteran (0.53) ✅
# insect_140.jpg → Dipteran (0.79) ✅
# insect_149.jpg → Dipteran (0.78) ✅
# insect_261.jpg → Dipteran (0.94) ✅
# insect_60.jpg → Dipteran (0.93) ✅
# insect_83.jpg → Dipteran (0.86) ✅
# insect_215.jpg → Dipteran (0.83) ✅
# insect_172.jpg → Dipteran (0.71) ✅
# insect_279.jpg → Dipteran (0.43) ✅
# insect_196.jpg → Other (0.47) ✅
# insect_17.jpg → Dipteran (0.50) ✅
# insect_15.jpg → Terrestrial (0.47) ✅
# insect_29.jpg → Dipteran (0.78) ✅
# insect_214.jpg → Dipteran (0.96) ✅
# insect_218.jpg → Dipteran (0.59) ✅
# insect_203.jpg → Dipteran (0.64) ✅
# insect_222.jpg → Other (0.47) ✅
# insect_240.jpg → Dipteran (0.67) ✅
# insect_157.jpg → Dipteran (0.54) ✅
# insect_104.jpg → Dipteran (0.84) ✅
# insect_294.jpg → Dipteran (0.68) ✅
# insect_10.jpg → Dipteran (0.58) ✅
# insect_130.jpg → Other (0.50) ✅
# insect_86.jpg → Other (0.48) ✅
# insect_108.jpg → Dipteran (0.93) ✅
# insect_274.jpg → Other (0.47) ✅
# insect_152.jpg → Dipteran (0.53) ✅
# insect_127.jpg → Dipteran (0.93) ✅
# insect_37.jpg → Dipteran (0.91) ✅
# insect_14.jpg → Other (0.71) ✅
# insect_247.jpg → Other (0.45) ✅
# insect_132.jpg → Dipteran (0.84) ✅
# insect_128.jpg → Dipteran (0.61) ✅
# insect_92.jpg → Dipteran (0.82) ✅
# insect_88.jpg → Dipteran (0.82) ✅
# insect_193.jpg → Dipteran (0.60) ✅
# insect_150.jpg → Dipteran (0.91) ✅
# insect_57.jpg → Dipteran (0.88) ✅
# insect_241.jpg → Dipteran (0.58) ✅
# insect_220.jpg → Other (0.45) ✅
# insect_216.jpg → Dipteran (0.88) ✅
# insect_120.jpg → Dipteran (0.91) ✅
# insect_76.jpg → Dipteran (0.57) ✅
# insect_182.jpg → Dipteran (0.79) ✅
# insect_195.jpg → Dipteran (0.92) ✅
# insect_2.jpg → Dipteran (0.83) ✅
# insect_168.jpg → Dipteran (0.44) ✅
# insect_178.jpg → Dipteran (0.82) ✅
# insect_114.jpg → Dipteran (0.51) ✅
# insect_30.jpg → Other (0.34) ✅
# insect_185.jpg → Dipteran (0.69) ✅
# insect_188.jpg → Dipteran (0.62) ✅
# insect_4.jpg → Dipteran (0.90) ✅
# insect_227.jpg → Dipteran (0.47) ✅
# insect_200.jpg → Dipteran (0.94) ✅
# insect_23.jpg → Dipteran (0.45) ✅
# insect_79.jpg → Dipteran (0.65) ✅
# insect_56.jpg → Dipteran (0.87) ✅
# insect_82.jpg → Dipteran (0.58) ✅
# insect_119.jpg → Dipteran (0.36) ➡ rerouted to 'Other'
# insect_238.jpg → Dipteran (0.56) ✅
# insect_207.jpg → Dipteran (0.69) ✅
# insect_32.jpg → Dipteran (0.91) ✅
# insect_199.jpg → Dipteran (0.66) ✅
# insect_169.jpg → Dipteran (0.89) ✅
# insect_228.jpg → Other (0.46) ✅
# insect_167.jpg → Other (0.42) ✅
# insect_96.jpg → Dipteran (0.75) ✅
# insect_141.jpg → Dipteran (0.55) ✅
# insect_93.jpg → Dipteran (0.73) ✅
# insect_148.jpg → Dipteran (0.49) ✅
# insect_173.jpg → Dipteran (0.63) ✅
# insect_290.jpg → Other (0.49) ✅
# insect_217.jpg → Dipteran (0.61) ✅
# insect_267.jpg → Other (0.48) ✅
# insect_39.jpg → Other (0.81) ✅
# insect_27.jpg → Dipteran (0.77) ✅
# insect_146.jpg → Dipteran (0.63) ✅
# insect_102.jpg → Dipteran (0.93) ✅
# insect_210.jpg → Dipteran (0.64) ✅
# insect_35.jpg → Dipteran (0.92) ✅
# insect_118.jpg → Other (0.39) ✅
# insect_1.jpg → Dipteran (0.95) ✅
# insect_175.jpg → Dipteran (0.59) ✅
# insect_65.jpg → Dipteran (0.70) ✅
# insect_54.jpg → Dipteran (0.89) ✅
# insect_90.jpg → Dipteran (0.79) ✅
# insect_70.jpg → Dipteran (0.87) ✅
# insect_135.jpg → Dipteran (0.82) ✅
# insect_256.jpg → Other (0.66) ✅
# insect_231.jpg → Dipteran (0.59) ✅
# insect_263.jpg → Other (0.45) ✅
# insect_237.jpg → Dipteran (0.67) ✅
# insect_11.jpg → Dipteran (0.78) ✅
# insect_87.jpg → Dipteran (0.84) ✅
# insect_134.jpg → Dipteran (0.78) ✅
# insect_101.jpg → Dipteran (0.69) ✅
# insect_164.jpg → Dipteran (0.86) ✅
# insect_276.jpg → Dipteran (0.54) ✅
# insect_74.jpg → Dipteran (0.78) ✅
# insect_219.jpg → Dipteran (0.88) ✅
# insect_69.jpg → Dipteran (0.90) ✅
# insect_205.jpg → Dipteran (0.90) ✅
# insect_125.jpg → Dipteran (0.54) ✅
# insect_252.jpg → Dipteran (0.69) ✅
# insect_244.jpg → Dipteran (0.55) ✅
# insect_124.jpg → Other (0.58) ✅
# insect_25.jpg → Dipteran (0.92) ✅
# insect_43.jpg → Dipteran (0.69) ✅
# insect_153.jpg → Dipteran (0.65) ✅
# insect_36.jpg → Dipteran (0.87) ✅
# insect_50.jpg → Caddisfly (0.65) ✅
# insect_71.jpg → Dipteran (0.61) ✅
# insect_266.jpg → Other (0.46) ✅
# insect_206.jpg → Dipteran (0.63) ✅
# insect_221.jpg → Dipteran (0.50) ✅
# insect_55.jpg → Dipteran (0.94) ✅
# insect_16.jpg → Dipteran (0.92) ✅
# insect_77.jpg → Dipteran (0.79) ✅
# insect_255.jpg → Dipteran (0.75) ✅
# insect_142.jpg → Dipteran (0.75) ✅
# insect_67.jpg → Dipteran (0.86) ✅
# insect_161.jpg → Dipteran (0.49) ✅
# insect_236.jpg → Dipteran (0.56) ✅
# insect_139.jpg → Dipteran (0.73) ✅
# insect_26.jpg → Dipteran (0.91) ✅
# insect_243.jpg → Other (0.47) ✅
# insect_233.jpg → Dipteran (0.50) ✅
# insect_154.jpg → Dipteran (0.55) ✅
# insect_33.jpg → Terrestrial (0.83) ✅
# insect_269.jpg → Other (0.64) ✅
# insect_283.jpg → Dipteran (0.47) ✅
# insect_64.jpg → Dipteran (0.86) ✅
# insect_41.jpg → Dipteran (0.94) ✅
# insect_259.jpg → Dipteran (0.49) ✅
# insect_170.jpg → Dipteran (0.91) ✅
# insect_159.jpg → Dipteran (0.89) ✅
# insect_95.jpg → Dipteran (0.77) ✅
# insect_81.jpg → Dipteran (0.93) ✅
# insect_245.jpg → Dipteran (0.83) ✅
# insect_155.jpg → Dipteran (0.70) ✅
# insect_62.jpg → Dipteran (0.95) ✅
# insect_126.jpg → Dipteran (0.45) ✅
# insect_212.jpg → Other (0.52) ✅
# insect_80.jpg → Dipteran (0.86) ✅
# insect_121.jpg → Dipteran (0.59) ✅
# insect_94.jpg → Dipteran (0.76) ✅
# insect_106.jpg → Dipteran (0.76) ✅
# insect_268.jpg → Dipteran (0.57) ✅
# insect_21.jpg → Dipteran (0.91) ✅
# insect_44.jpg → Dipteran (0.89) ✅
# insect_165.jpg → Dipteran (0.46) ✅
# insect_248.jpg → Dipteran (0.91) ✅
# insect_242.jpg → Dipteran (0.49) ✅
# insect_251.jpg → Dipteran (0.53) ✅
# insect_53.jpg → Dipteran (0.90) ✅
# insect_278.jpg → Dipteran (0.45) ✅
# insect_234.jpg → Other (0.49) ✅
# insect_34.jpg → Dipteran (0.60) ✅
# insect_286.jpg → Dipteran (0.77) ✅
# insect_45.jpg → Dipteran (0.80) ✅
# insect_192.jpg → Dipteran (0.85) ✅
# insect_260.jpg → Dipteran (0.75) ✅
# insect_180.jpg → Dipteran (0.70) ✅
# insect_58.jpg → Dipteran (0.49) ✅
# insect_28.jpg → Dipteran (0.81) ✅
# insect_19.jpg → Dipteran (0.64) ✅
# insect_254.jpg → Other (0.61) ✅
# insect_280.jpg → Other (0.66) ✅
# insect_8.jpg → Dipteran (0.91) ✅
# insect_246.jpg → Dipteran (0.45) ✅
# insect_75.jpg → Dipteran (0.54) ✅
# insect_197.jpg → Dipteran (0.46) ✅
# insect_187.jpg → Dipteran (0.90) ✅
# insect_176.jpg → Dipteran (0.76) ✅
# insect_194.jpg → Dipteran (0.93) ✅
# insect_20.jpg → Other (0.39) ✅
# insect_123.jpg → Dipteran (0.67) ✅
# insect_225.jpg → Dipteran (0.54) ✅
# insect_293.jpg → Dipteran (0.49) ✅
# insect_136.jpg → Dipteran (0.92) ✅
# insect_235.jpg → Dipteran (0.82) ✅
# insect_3.jpg → Dipteran (0.87) ✅
# insect_78.jpg → Dipteran (0.71) ✅
# insect_272.jpg → Other (0.46) ✅
# insect_284.jpg → Dipteran (0.90) ✅
# insect_223.jpg → Dipteran (0.42) ✅
# insect_270.jpg → Dipteran (0.74) ✅
# insect_110.jpg → Dipteran (0.70) ✅
# insect_177.jpg → Dipteran (0.69) ✅
# insect_9.jpg → Other (0.89) ✅
# insect_6.jpg → Other (0.84) ✅
# insect_38.jpg → Other (0.73) ✅
# insect_265.jpg → Dipteran (0.65) ✅
# insect_179.jpg → Dipteran (0.57) ✅
# insect_189.jpg → Dipteran (0.84) ✅
# insect_191.jpg → Dipteran (0.43) ✅
# insect_158.jpg → Dipteran (0.60) ✅
# insect_253.jpg → Other (0.53) ✅
# insect_250.jpg → Other (0.48) ✅
# insect_131.jpg → Other (0.34) ✅
# insect_287.jpg → Other (0.44) ✅
# insect_143.jpg → Dipteran (0.79) ✅
# insect_160.jpg → Dipteran (0.38) ➡ rerouted to 'Other'
# insect_201.jpg → Dipteran (0.77) ✅
# insect_100.jpg → Dipteran (0.46) ✅
# insect_190.jpg → Dipteran (0.80) ✅
# insect_46.jpg → Dipteran (0.82) ✅
# insect_258.jpg → Dipteran (0.64) ✅
#
# Summary CSV saved to: class_summary.csv
# Class Distribution:
# Dipteran: 244 times
# Other: 47 times
# Terrestrial: 3 times
# Caddisfly: 1 times
# Mayfly: 0 times
# Stonefly: 0 times
# COCO annotation JSON saved to coco_annotations.json

# %% [markdown]
# ## Run the code below to visualise results on the original image

# %%
import json
import cv2
import os
import matplotlib.pyplot as plt

def get_color_map(categories):
    """Assigns a unique BGR color to each class"""
    base_colors = [
        (255, 0, 0),    # Blue
        (0, 255, 0),    # Green
        (0, 0, 255),    # Red
        (255, 255, 0),  # Cyan
        (255, 0, 255),  # Magenta
        (0, 255, 255),  # Yellow
        (128, 0, 128),  # Purple
        (0, 128, 128),  # Teal
        (128, 128, 0),  # Olive
        (255, 165, 0),  # Orange
    ]
    color_map = {}
    for i, cat in enumerate(categories):
        color_map[cat['id']] = base_colors[i % len(base_colors)]
    return color_map

def visualize_coco_annotations(coco_json_path, image_folder, save_output=False, output_path=None):
    with open(coco_json_path, 'r') as f:
        coco = json.load(f)

    images = {img['id']: img for img in coco['images']}
    categories = {cat['id']: cat['name'] for cat in coco['categories']}
    color_map = get_color_map(coco['categories'])

    annotations = coco['annotations']

    for image_id, image_info in images.items():
        img_path = os.path.join(image_folder, image_info['file_name'])
        img = cv2.imread(img_path)
        if img is None:
            print(f"⚠️ Skipping {img_path} (not found)")
            continue

        for ann in [a for a in annotations if a['image_id'] == image_id]:
            x, y, w, h = map(int, ann['bbox'])
            category_id = ann['category_id']
            category_name = categories[category_id]
            color = color_map[category_id]

            cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv2.putText(img, category_name, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
                        0.6, color, 2, cv2.LINE_AA)

        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.figure(figsize=(10, 10))
        plt.imshow(img_rgb)
        plt.axis('off')
        plt.title(f"Annotated: {image_info['file_name']}")

        if save_output:
            output_dir = os.path.dirname(output_path)
            if output_dir:
                os.makedirs(output_dir, exist_ok=True)
            cv2.imwrite(output_path, img)
            print(f"✅ Saved annotated image to {output_path}")
        else:
            plt.show()


# Example usage
visualize_coco_annotations(
    coco_json_path='coco_annotations.json',
    image_folder='/content',  # Folder where the original image is
    save_output=True,        # Set to True to save instead of show
    output_path='./annotated_output.jpg')
# Out:
# ✅ Saved annotated image to ./annotated_output.jpg

# %% [markdown]
# ## Run cell below to download csv files and image prediction folder

# %%
from google.colab import files

# Download csv files
files.download('/content/detailed_predictions.csv')
files.download('/content/class_summary.csv')

#Download annotation
files.download('/content/coco_annotations.json')

#Download annotated image
files.download('/content/annotated_output.jpg')

#Download image folder
import shutil

# Zip the folder
shutil.make_archive('/content/results', 'zip', '/content/results')

# Download the zip file
files.download('/content/results.zip')

# %% [markdown]
# ## Want to run inference with another image? Run cell below to clear out current results.

# %%
# !rm -rf /content/cropped_results
# !rm -rf /content/results/
# !rm -rf /content/detailed_predictions.csv
# !rm -rf /content/class_summary.csv
# !rm -rf /content/results.zip
# !rm -rf /content/coco_annotations.json
# !rm -rf /content/annotated_output.jpg
